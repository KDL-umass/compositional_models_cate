# %%
import pandas as pd
import numpy as np 
from matplotlib import pyplot as plt

# %%
# load module_files 
path = "/work/pi_jensen_umass_edu/ppruthi_umass_edu/compositional_models_cate/domains/synthetic_data/csvs/fixed_structure_False_outcomes_parallel_systematic_True"

# for each module file, load the data and plot x vs y
for i in range(1, 11):
    df = pd.read_csv(f"{path}/module_{i}.csv")
    plt.figure(figsize=(10, 10))
    plt.scatter(df["feature_0"], df["output"])
